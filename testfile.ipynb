# %%
from API_Main import TravelOffer_RS
# Out:
# >>>
# The request of TEST USER has been generated in
#  /Users/gleonardo/Downloads/TravelOffer_Recommendation-main/TEST_DATA/RequestJson/requestInfo.json
# >>>
# TSP PHASE has been checked over, see the results in :
#  /Users/gleonardo/Downloads/TravelOffer_Recommendation-main/TEST_DATA/CHECK_Metadata/TSPresults.csv

# %%
test = TravelOffer_RS()

# %%
test.show()
# Out:
# ==================================================================
#
#  API LIST:
#
#
#
# >>>"API_USER_TRAIN":
#
#        -used by the administrator to train or update the model for user
#
#
#
# >>>"API_USER_PREDICT":
#
#        -used by the user to get the recommendation list
#
#
#
# >>>"API_USER_FEEDBACK":
#
#        -used by the administrator to update the historical records according to the user's decision
#
#
#
# ----------------------------------------
#
#  CHECK LIST:
#
#
#
# >>>"CHECK_Req2TSP":
#
#        -check the phase from user to tsp
#
#
#
# >>>"CHECK_Req2Categorizer":
#
#        -check the pahse from user to categorizer
#
#
#
# >>>"CHECK_USER2UPDATE_PROFILE":
#
#        -check the functionality that the user want to update his/her profile
#
#
#
# >>>"CHECK_USER2RESPONSE":
#
#        -check the predict function for an old user
#
#
#
# >>>"CHECK_ColdUserResponse":
#
#        -check the predict function for a cold user
#
#
#
# >>>"CHECK_USER_FEEDBACK":
#
#        -check the feedback function
#
#
#
# >>>"CHECK_ADMINISTRATOR2CLASSIFIER_TRAIN":
#
#        -check the functionality that the administrator want to train/update the classifier model
#
#
#
# >>>"CHECK_ADMINISTRATOR2CLUSTER_TRAIN":
#
#        -check the functionality that the administrator want to train/update the cluster model
#
#
#
#  -----------------------------------------
#
#  [Using help() to check the details of the function ]

# %%
test.help()
# Out:
# ==================================================================
#
# API_USER_PREDICT(username,req,Jsonfile=None,df_profile=None)
#
#
#
# [username] the person for whom you try to predict, can be an new_cold_user with a random name.
#
#            can be a cold_user whoes #historical data less than 20,
#
#            can be an old_user ,like 'OLDUSER1'
#
# [req] is a dict that contains the request of the user, if NONE req will be the default request dict==> .tsp.TEST_search_option_dict.
#
# [Jsonfile] is a path of the request Jsonfile, if given system will use the req in Jsonfile.
#
# [df_profile] If exist, update user profile with this data.
#
# [reClusterTag] Always set as False
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  You can use the following default parameters :
#
#  [username] self.OLD_USER ==> an old user / self.COLD_USER ==> an cold user
#
#  [req] self.req
#
#  [df_profile] self.df_profile , do changes like 'df_profile.loc[0,'User ID] = username' before using
#
# API_USER_PREDICT not in the help list, use show() to check all the function

# %%
test.API_USER_PREDICT(test.OLD_USER,test.req)
# Out:
# >>>
# The request of TEST USER has been generated in
#  /Users/gleonardo/Downloads/TravelOffer_Recommendation-main/TEST_DATA/RequestJson/requestInfo.json
# =======================================================================================================
#
# Dear OLDUSER1 :
#
# According to your request, we recommend you consider the followiing travel offers.
#
#      Travel Offer ID Starting point Destination  \
# 0    202105120304399         Dublin       Milan
# 1   2021051203043933         Dublin       Milan
# 2   2021051203043930         Dublin       Milan
# 3   2021051203043934         Dublin       Milan
# 4    202105120304394         Dublin       Milan
# 11  2022-11-02 08:53
# 12  2022-11-02 08:53
# 13  2022-11-02 08:53
# 14  2022-11-02 08:53
# 15  2022-11-02 08:53
# 16  2022-11-02 08:53
# 17  2022-11-02 08:53
# 18  2022-11-02 08:53
# 19  2022-11-02 08:53
# 20  2022-11-02 08:53
# 21  2022-11-02 08:53
# 22  2022-11-02 08:53
# 23  2022-11-02 08:53
# 24  2022-11-02 08:53
# 25  2022-11-02 08:53
# 26  2022-11-02 08:53
# 27  2022-11-02 08:53
# 28  2022-11-02 08:53
# 29  2022-11-02 08:53
#
# ---------------------------------------------------------------------------------------------------------
#
# The response_code for this time is  20210512_03045184
# '20210512_03045184'

# %%
test.help()
# Out:
# ==================================================================
#
# API_USER_PREDICT(username,req,Jsonfile=None,df_profile=None)
#
#
#
# [username] the person for whom you try to predict, can be an new_cold_user with a random name.
#
#            can be a cold_user whoes #historical data less than 20,
#
#            can be an old_user ,like 'OLDUSER1'
#
# [req] is a dict that contains the request of the user, if NONE req will be the default request dict==> .tsp.TEST_search_option_dict.
#
# [Jsonfile] is a path of the request Jsonfile, if given system will use the req in Jsonfile.
#
# [df_profile] If exist, update user profile with this data.
#
# [reClusterTag] Always set as False
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  You can use the following default parameters :
#
#  [username] self.OLD_USER ==> an old user / self.COLD_USER ==> an cold user
#
#  [req] self.req
#
#  [df_profile] self.df_profile , do changes like 'df_profile.loc[0,'User ID] = username' before using
#
# API_USER_PREDICT not in the help list, use show() to check all the function

# %%
newuser = 'NewUser02'
new_profile = test.df_profile
new_profile.loc[0,'User ID'] = newuser

# %%
test.API_USER_PREDICT('NewUser02',req=test.req,df_profile=new_profile)
# Out:
# Profile Has Been Updated in  /Users/gleonardo/Downloads/TravelOffer_Recommendation-main/TEST_DATA/USER_PROFILE/NewUser02.csv
#
# >>>
# The request of TEST USER has been generated in
#  /Users/gleonardo/Downloads/TravelOffer_Recommendation-main/TEST_DATA/RequestJson/requestInfo.json
# The ClusterNo for the user is : [0]
# DONE! THE Pre trained model has been copied into the cold user
# =======================================================================================================
#
# Dear NewUser02 :
#
# According to your request, we recommend you consider the followiing travel offers.
#
#      Travel Offer ID Starting point Destination  \
# 0   2021051203051915         Dublin       Milan
# 1   2021051203051948         Dublin       Milan
# 2   2021051203051922         Dublin       Milan
# 3   2021051203051942         Dublin       Milan
# 4   2021051203051935         Dublin       Milan
# 5   2021051203051930         Dublin       Milan
# 6   2021051203051916         Dublin       Milan
# 7   2021051203051924         Dublin       Milan
# 8    202105120305192         Dublin       Milan
# 9   2021051203051925         Dublin       Milan
# 10  2021051203051945         Dublin       Milan
# 11  2021051203051934         Dublin       Milan
# 12   202105120305193         Dublin       Milan
# 13  2021051203051920         Dublin       Milan
# 14  2021051203051912         Dublin       Milan
# 15  2021051203051936         Dublin       Milan
# 16   202105120305191         Dublin       Milan
# 17  2021051203051918         Dublin       Milan
# 18  2021051203051926         Dublin       Milan
# 19  2021051203051928         Dublin       Milan
# 20   202105120305195         Dublin       Milan
# 6   2022-11-02 08:53
# 7   2022-11-02 08:53
# 8   2022-11-02 08:53
# 9   2022-11-02 08:53
# 10  2022-11-02 08:53
# 11  2022-11-02 08:53
# 12  2022-11-02 08:53
# 13  2022-11-02 08:53
# 14  2022-11-02 08:53
# 15  2022-11-02 08:53
# 16  2022-11-02 08:53
# 17  2022-11-02 08:53
# 18  2022-11-02 08:53
# 19  2022-11-02 08:53
# 20  2022-11-02 08:53
# 21  2022-11-02 08:53
# 22  2022-11-02 08:53
# 23  2022-11-02 08:53
# 24  2022-11-02 08:53
# 25  2022-11-02 08:53
# 26  2022-11-02 08:53
# 27  2022-11-02 08:53
# 28  2022-11-02 08:53
# 29  2022-11-02 08:53
#
# ---------------------------------------------------------------------------------------------------------
#
# The response_code for this time is  20210512_03051997
# '20210512_03051997'

# %%
print(test.df_profile)
# Out:
#                     TimeStamp    User ID Date Of Birth    city  country  \
# 0  2021-04-30 05:05:35.582118  NewUser01    1973-08-02  Dublin  Ireland
#
#                                         Loyalty Card  \
# 0  ['Grand Voyageur', 'Golden Card', 'Cartafreccia']
#
#                                         Payment Card  \
# 0  ['Apple Wallet', 'Google Wallet', 'Visa', 'Mas...
#
#                                             PRM Type  \
# 0  ['Pregnant woman', 'Older person', 'Person wit...
#
#                    Preferred means of transportation  \
# 0  ['Intercity', 'Urban', 'Funicular', 'Trolely B...
#
#                                    Preferred carrier    Class    Seat  \
# 0  [4.5, 2.5, 4.5, 3.5, 3.0, 1.5, 5.0, 1.5, 3.5, ...  Economy  Window
#
#         Refund Type
# 0  Automatic refund

# %%
test.API_USER_TRAIN(test.OLD_USER)
# Out:
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Start Searching The best recommender<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Current Checking Recommender is >>>> [[ SVC ]]
#
# Time Consuming for this fit is :0.8370189666748047
#
# ===> val. score: 0.6381578947368421
#
# ===> best parameter: OrderedDict([('C', 0.07825705299241592), ('degree', 2), ('gamma', 7.102554623183214e-05), ('kernel', 'poly'), ('probability', True)])
#
# ===> Actual Estimator is: SVC(C=0.07825705299241592, break_ties=False, cache_size=200, class_weight=None,
#     coef0=0.0, decision_function_shape='ovr', degree=2,
#     gamma=7.102554623183214e-05, kernel='poly', max_iter=-1, probability=True,
#     random_state=None, shrinking=True, tol=0.001, verbose=False)
#
#
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Current Checking Recommender is >>>> [[ DecisionTreeClassifier ]]
#
# Time Consuming for this fit is :0.0400540828704834
#
# ===> val. score: 0.5855263157894737
#
# ===> best parameter: OrderedDict([('criterion', 'gini'), ('max_depth', 5), ('max_features', 22), ('max_leaf_nodes', 16), ('min_samples_leaf', 11)])
#
# ===> Actual Estimator is: DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=5, max_features=22, max_leaf_nodes=16,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=11, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')
#
#
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Current Checking Recommender is >>>> [[ LogisticRegression ]]
#
# Time Consuming for this fit is :0.6076376438140869
#
# ===> val. score: 0.555921052631579
#
# ===> best parameter: OrderedDict([('C', 0.9994688770332163), ('fit_intercept', True), ('solver', 'sag')])
#
# ===> Actual Estimator is: LogisticRegression(C=0.9994688770332163, class_weight=None, dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='sag', tol=0.0001, verbose=0,
#                    warm_start=False)
#
#
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Current Checking Recommender is >>>> [[ RandomForestClassifier ]]
#
# Time Consuming for this fit is :1.4647748470306396
#
# ===> val. score: 0.6052631578947368
#
# ===> best parameter: OrderedDict([('bootstrap', False), ('criterion', 'entropy'), ('max_depth', 33), ('max_features', 26), ('n_estimators', 88)])
#
# ===> Actual Estimator is: RandomForestClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=33, max_features=26,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=88,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
#
#
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Current Checking Recommender is >>>> [[ KNeighborsClassifier_uniform ]]
#
# Time Consuming for this fit is :0.11458492279052734
#
# ===> val. score: 0.6414473684210527
#
# ===> best parameter: OrderedDict([('algorithm', 'ball_tree'), ('n_neighbors', 25)])
#
# ===> Actual Estimator is: KNeighborsClassifier(algorithm='ball_tree', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=25, p=2,
#                      weights='uniform')
#
#
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Current Checking Recommender is >>>> [[ KNeighborsClassifier_distance ]]
#
# Time Consuming for this fit is :0.5775928497314453
#
# ===> val. score: 0.6381578947368421
#
# ===> best parameter: OrderedDict([('algorithm', 'ball_tree'), ('n_neighbors', 21), ('p', 5)])
#
# ===> Actual Estimator is: KNeighborsClassifier(algorithm='ball_tree', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=21, p=5,
#                      weights='distance')
#
#
#
# ----------------------------------------------------------------------------------------------------------------
#
# SEARCHING FINISH :
#  The best recommder is KNeighborsClassifier_uniform
#  its tune parameter is OrderedDict([('algorithm', 'ball_tree'), ('n_neighbors', 25)])
#  its score is 0.6414473684210527
#  its evaluation score is 0 (0 means do not have the evaluation set)
#  its model train time is 0.11458492279052734
#  The actually estimator is KNeighborsClassifier(algorithm='ball_tree', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=25, p=2,
#                      weights='uniform')
#
# ----------------------------------------------------------------------------------------------------------------
#
# MODEL HAS BEEN SAVED IN  /Users/gleonardo/Downloads/TravelOffer_Recommendation-main/TEST_DATA/CLASSIFIER/MODEL/best_model_OLDUSER1_all_latest.m
# INFO HAS BEEN SAVED IN  /Users/gleonardo/Downloads/TravelOffer_Recommendation-main/TEST_DATA/CLASSIFIER/INFO/best_model_OLDUSER1_all_latest.npy

# %%
test.API_USER_TRAIN(test.COLD_USER)
# Out:
# INFO HAS BEEN SAVED IN  /Users/gleonardo/Downloads/TravelOffer_Recommendation-main/TEST_DATA/CLUSTER_FOLDER/CLUSTER_MODEL_INFO/ClusterModelINFO.npy
# INFO HAS BEEN SAVED IN  /Users/gleonardo/Downloads/TravelOffer_Recommendation-main/TEST_DATA/CLUSTER_FOLDER/CLUSTER_MODEL_INFO/ClusterModelINFO.npy
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 9.800000000000011    MIN_SAMPLES : 5
#
# SCORE : -0.010024475999310785
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.9056603773584906
#
# STATS : [5]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 9.850000000000012    MIN_SAMPLES : 5
#
# SCORE : -0.010024475999310785
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.9056603773584906
#
# STATS : [5]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 9.900000000000013    MIN_SAMPLES : 5
#
# SCORE : -0.010024475999310785
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.9056603773584906
#
# STATS : [5]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 9.950000000000014    MIN_SAMPLES : 5
#
# SCORE : -0.010024475999310785
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.9056603773584906
#
# STATS : [5]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.000000000000014    MIN_SAMPLES : 5
#
# SCORE : -0.010024475999310785
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.9056603773584906
#
# STATS : [5]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.050000000000015    MIN_SAMPLES : 5
#
# SCORE : -0.010024475999310785
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.9056603773584906
#
# STATS : [5]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.100000000000016    MIN_SAMPLES : 5
#
# SCORE : -0.03343509204064148
#
#
# N_CLUSRERS : 2 RATIO_OUTLINERS : 0.8113207547169812
#
# STATS : [5 5]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.150000000000016    MIN_SAMPLES : 5
#
# SCORE : -0.03343509204064148
#
#
# N_CLUSRERS : 2 RATIO_OUTLINERS : 0.8113207547169812
#
# STATS : [5 5]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.200000000000017    MIN_SAMPLES : 5
#
# SCORE : -0.026277177698091576
#
#
# N_CLUSRERS : 2 RATIO_OUTLINERS : 0.7735849056603774
#
# STATS : [7 5]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.200000000000017    MIN_SAMPLES : 6
#
# SCORE : -0.014189944421453294
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8867924528301887
#
# STATS : [6]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.250000000000018    MIN_SAMPLES : 5
#
# SCORE : -0.026277177698091576
#
#
# N_CLUSRERS : 2 RATIO_OUTLINERS : 0.7735849056603774
#
# STATS : [7 5]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.250000000000018    MIN_SAMPLES : 6
#
# SCORE : -0.014189944421453294
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8867924528301887
#
# STATS : [6]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.300000000000018    MIN_SAMPLES : 5
#
# SCORE : -0.026277177698091576
#
#
# N_CLUSRERS : 2 RATIO_OUTLINERS : 0.7735849056603774
#
# STATS : [7 5]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.300000000000018    MIN_SAMPLES : 6
#
# SCORE : -0.014189944421453294
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8867924528301887
#
# STATS : [6]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.35000000000002    MIN_SAMPLES : 5
#
# SCORE : -0.021167793074876012
#
#
# N_CLUSRERS : 2 RATIO_OUTLINERS : 0.7547169811320755
#
# STATS : [8 5]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.35000000000002    MIN_SAMPLES : 6
#
# SCORE : -0.010925063084922854
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8679245283018868
#
# STATS : [7]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.35000000000002    MIN_SAMPLES : 7
#
# SCORE : -0.010925063084922854
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8679245283018868
#
# STATS : [7]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.40000000000002    MIN_SAMPLES : 5
#
# SCORE : -0.01970340067321144
#
#
# N_CLUSRERS : 2 RATIO_OUTLINERS : 0.7358490566037735
#
# STATS : [9 5]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.40000000000002    MIN_SAMPLES : 6
#
# SCORE : -0.008489550649894375
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8490566037735849
#
# STATS : [8]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.40000000000002    MIN_SAMPLES : 7
#
# SCORE : -0.008489550649894375
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8490566037735849
#
# STATS : [8]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.40000000000002    MIN_SAMPLES : 8
#
# SCORE : -0.008489550649894375
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8490566037735849
#
# STATS : [8]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.45000000000002    MIN_SAMPLES : 5
#
# SCORE : -0.01970340067321144
#
#
# N_CLUSRERS : 2 RATIO_OUTLINERS : 0.7358490566037735
#
# STATS : [9 5]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.45000000000002    MIN_SAMPLES : 6
#
# SCORE : -0.008489550649894375
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8490566037735849
#
# STATS : [8]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.45000000000002    MIN_SAMPLES : 7
#
# SCORE : -0.008489550649894375
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8490566037735849
#
# STATS : [8]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.45000000000002    MIN_SAMPLES : 8
#
# SCORE : -0.008489550649894375
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8490566037735849
#
# STATS : [8]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.500000000000021    MIN_SAMPLES : 5
#
# SCORE : -0.01970340067321144
#
#
# N_CLUSRERS : 2 RATIO_OUTLINERS : 0.7358490566037735
#
# STATS : [9 5]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.500000000000021    MIN_SAMPLES : 6
#
# SCORE : -0.008489550649894375
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8490566037735849
#
# STATS : [8]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.500000000000021    MIN_SAMPLES : 7
#
# SCORE : -0.008489550649894375
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8490566037735849
#
# STATS : [8]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.500000000000021    MIN_SAMPLES : 8
#
# SCORE : -0.008489550649894375
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8490566037735849
#
# STATS : [8]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.550000000000022    MIN_SAMPLES : 5
#
# SCORE : -0.01970340067321144
#
#
# N_CLUSRERS : 2 RATIO_OUTLINERS : 0.7358490566037735
#
# STATS : [9 5]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.550000000000022    MIN_SAMPLES : 6
#
# SCORE : -0.008489550649894375
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8490566037735849
#
# STATS : [8]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.550000000000022    MIN_SAMPLES : 7
#
# SCORE : -0.008489550649894375
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8490566037735849
#
# STATS : [8]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.550000000000022    MIN_SAMPLES : 8
#
# SCORE : -0.008489550649894375
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8490566037735849
#
# STATS : [8]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.600000000000023    MIN_SAMPLES : 5
#
# SCORE : -0.01970340067321144
#
#
# N_CLUSRERS : 2 RATIO_OUTLINERS : 0.7358490566037735
#
# STATS : [9 5]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.600000000000023    MIN_SAMPLES : 6
#
# SCORE : -0.006735571176543776
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8301886792452831
#
# STATS : [9]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.600000000000023    MIN_SAMPLES : 7
#
# SCORE : -0.008489550649894375
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8490566037735849
#
# STATS : [8]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.600000000000023    MIN_SAMPLES : 8
#
# SCORE : -0.008489550649894375
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8490566037735849
#
# STATS : [8]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.650000000000023    MIN_SAMPLES : 5
#
# SCORE : -0.01970340067321144
#
#
# N_CLUSRERS : 2 RATIO_OUTLINERS : 0.7358490566037735
#
# STATS : [9 5]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.650000000000023    MIN_SAMPLES : 6
#
# SCORE : -0.006735571176543776
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8301886792452831
#
# STATS : [9]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.650000000000023    MIN_SAMPLES : 7
#
# SCORE : -0.008489550649894375
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8490566037735849
#
# STATS : [8]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.650000000000023    MIN_SAMPLES : 8
#
# SCORE : -0.008489550649894375
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8490566037735849
#
# STATS : [8]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.700000000000024    MIN_SAMPLES : 5
#
# SCORE : -0.01970340067321144
#
#
# N_CLUSRERS : 2 RATIO_OUTLINERS : 0.7358490566037735
#
# STATS : [9 5]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.700000000000024    MIN_SAMPLES : 6
#
# SCORE : -0.006735571176543776
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8301886792452831
#
# STATS : [9]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.700000000000024    MIN_SAMPLES : 7
#
# SCORE : -0.008489550649894375
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8490566037735849
#
# STATS : [8]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.700000000000024    MIN_SAMPLES : 8
#
# SCORE : -0.008489550649894375
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8490566037735849
#
# STATS : [8]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.750000000000025    MIN_SAMPLES : 5
#
# SCORE : -0.00951273693256182
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.6792452830188679
#
# STATS : [17]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.750000000000025    MIN_SAMPLES : 6
#
# SCORE : -0.006735571176543776
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8301886792452831
#
# STATS : [9]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.750000000000025    MIN_SAMPLES : 7
#
# SCORE : -0.008489550649894375
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8490566037735849
#
# STATS : [8]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.750000000000025    MIN_SAMPLES : 8
#
# SCORE : -0.008489550649894375
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8490566037735849
#
# STATS : [8]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.800000000000026    MIN_SAMPLES : 5
#
# SCORE : 0.0007589607249204323
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.6226415094339622
#
# STATS : [20]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.800000000000026    MIN_SAMPLES : 6
#
# SCORE : -0.015336523294485272
#
#
# N_CLUSRERS : 2 RATIO_OUTLINERS : 0.660377358490566
#
# STATS : [12  6]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.800000000000026    MIN_SAMPLES : 7
#
# SCORE : -0.008489550649894375
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8490566037735849
#
# STATS : [8]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.800000000000026    MIN_SAMPLES : 8
#
# SCORE : -0.008489550649894375
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8490566037735849
#
# STATS : [8]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.850000000000026    MIN_SAMPLES : 5
#
# SCORE : 0.010592501764280414
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.5471698113207547
#
# STATS : [24]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.850000000000026    MIN_SAMPLES : 6
#
# SCORE : -0.011760092316225709
#
#
# N_CLUSRERS : 2 RATIO_OUTLINERS : 0.6415094339622641
#
# STATS : [13  6]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.850000000000026    MIN_SAMPLES : 7
#
# SCORE : -0.0003888161643889429
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.7735849056603774
#
# STATS : [12]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.850000000000026    MIN_SAMPLES : 8
#
# SCORE : -0.008489550649894375
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8490566037735849
#
# STATS : [8]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.900000000000027    MIN_SAMPLES : 5
#
# SCORE : 0.01298945216506174
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.5094339622641509
#
# STATS : [26]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.900000000000027    MIN_SAMPLES : 6
#
# SCORE : -0.009434372839015409
#
#
# N_CLUSRERS : 2 RATIO_OUTLINERS : 0.6226415094339622
#
# STATS : [14  6]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.900000000000027    MIN_SAMPLES : 7
#
# SCORE : 0.0028160135865471286
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.7547169811320755
#
# STATS : [13]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.900000000000027    MIN_SAMPLES : 8
#
# SCORE : -0.006735571176543776
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8301886792452831
#
# STATS : [9]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.900000000000027    MIN_SAMPLES : 9
#
# SCORE : -0.006735571176543776
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8301886792452831
#
# STATS : [9]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.950000000000028    MIN_SAMPLES : 5
#
# SCORE : 0.025170118783698396
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.41509433962264153
#
# STATS : [31]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.950000000000028    MIN_SAMPLES : 6
#
# SCORE : -0.0006324190356261605
#
#
# N_CLUSRERS : 2 RATIO_OUTLINERS : 0.5849056603773585
#
# STATS : [16  6]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.950000000000028    MIN_SAMPLES : 7
#
# SCORE : -0.002726721807885595
#
#
# N_CLUSRERS : 2 RATIO_OUTLINERS : 0.6226415094339622
#
# STATS : [14  6]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.950000000000028    MIN_SAMPLES : 8
#
# SCORE : -0.006735571176543776
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8301886792452831
#
# STATS : [9]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 10.950000000000028    MIN_SAMPLES : 9
#
# SCORE : -0.006735571176543776
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8301886792452831
#
# STATS : [9]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 11.000000000000028    MIN_SAMPLES : 5
#
# SCORE : 0.028382962184280176
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.37735849056603776
#
# STATS : [33]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 11.000000000000028    MIN_SAMPLES : 6
#
# SCORE : -0.0006324190356261605
#
#
# N_CLUSRERS : 2 RATIO_OUTLINERS : 0.5849056603773585
#
# STATS : [16  6]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 11.000000000000028    MIN_SAMPLES : 7
#
# SCORE : -0.002726721807885595
#
#
# N_CLUSRERS : 2 RATIO_OUTLINERS : 0.6226415094339622
#
# STATS : [14  6]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 11.000000000000028    MIN_SAMPLES : 8
#
# SCORE : -0.006735571176543776
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8301886792452831
#
# STATS : [9]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 11.000000000000028    MIN_SAMPLES : 9
#
# SCORE : -0.006735571176543776
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.8301886792452831
#
# STATS : [9]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 0
#
# BEST_MIN_SAMPLES : 0
#
# BEST_SCORE : 0
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 11.05000000000003    MIN_SAMPLES : 5
#
# SCORE : 0.028382962184280176
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.37735849056603776
#
# STATS : [33]
#
#
# ----------------------------------------------------------
#
# ...
# BEST_MIN_SAMPLES : 8
#
# BEST_SCORE : 0.009023677211671096
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 13.850000000000069    MIN_SAMPLES : 5
#
# SCORE : 0.17226000354718557
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.018867924528301886
#
# STATS : [52]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 11.350000000000033
#
# BEST_MIN_SAMPLES : 8
#
# BEST_SCORE : 0.009023677211671096
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 13.850000000000069    MIN_SAMPLES : 6
#
# SCORE : 0.17226000354718557
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.018867924528301886
#
# STATS : [52]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 11.350000000000033
#
# BEST_MIN_SAMPLES : 8
#
# BEST_SCORE : 0.009023677211671096
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 13.850000000000069    MIN_SAMPLES : 7
#
# SCORE : 0.17226000354718557
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.018867924528301886
#
# STATS : [52]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 11.350000000000033
#
# BEST_MIN_SAMPLES : 8
#
# BEST_SCORE : 0.009023677211671096
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 13.850000000000069    MIN_SAMPLES : 8
#
# SCORE : 0.17226000354718557
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.018867924528301886
#
# STATS : [52]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 11.350000000000033
#
# BEST_MIN_SAMPLES : 8
#
# BEST_SCORE : 0.009023677211671096
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# >>> Current parameters and its score:
#
# EPS : 13.850000000000069    MIN_SAMPLES : 9
#
# SCORE : 0.17226000354718557
#
#
# N_CLUSRERS : 1 RATIO_OUTLINERS : 0.018867924528301886
#
# STATS : [52]
#
#
# ----------------------------------------------------------
#
# >>>Curr BEST PARAMETERS:
#
# BEST_EPS : 11.350000000000033
#
# BEST_MIN_SAMPLES : 8
#
# BEST_SCORE : 0.009023677211671096
#
#
#
#        eps  min_samples  n_clusters     score  ratio_outliners  outliners  \
# 105  11.35            8           2  0.009024         0.396226         21
#
#        stats
# 105  [24  8]
#
# ===============================================================
#
# >>> The BEST parameters for DBSCAN algorithm is:
#
# >>> eps : 11.350000000000033
#
# >>> min_samples: 8
#
# >>> its sihouette coeficient score is : 0.009023677211671096
#
#
# CLUSTER MODEL HAS BEEN SAVED IN  /Users/gleonardo/Downloads/TravelOffer_Recommendation-main/TEST_DATA/CLUSTER_FOLDER/CLUSTER_MODEL_INFO/Zero_cluserFitScaler.m
# CLUSTER MODEL HAS BEEN SAVED IN  /Users/gleonardo/Downloads/TravelOffer_Recommendation-main/TEST_DATA/CLUSTER_FOLDER/CLUSTER_MODEL_INFO/DBSCAN_newest_cluster_model.m
# INFO HAS BEEN SAVED IN  /Users/gleonardo/Downloads/TravelOffer_Recommendation-main/TEST_DATA/CLUSTER_FOLDER/CLUSTER_MODEL_INFO/DBSCAN_CLUSTER_MODEL_INFO.npy
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# =============================================================
#
# >>> Cluster 0 :
#
# >>> Contains trained users :
#
# >>> ['COLDUSER1', 'CLUSTERtrain_43', 'CLUSTERtrain_25', 'CLUSTERtrain_31', 'CLUSTERtrain_19', 'CLUSTERtrain_18', 'CLUSTERtrain_32', 'CLUSTERtrain_27', 'CLUSTERtrain_37', 'CLUSTERtrain_22', 'CLUSTERtrain_36', 'CLUSTERtrain_34', 'CLUSTERtrain_35', 'CLUSTERtrain_21', 'CLUSTERtrain_39', 'CLUSTERtrain_11', 'CLUSTERtrain_13', 'OLDUSER1', 'CLUSTERtrain_28', 'CLUSTERtrain_0', 'CLUSTERtrain_1', 'CLUSTERtrain_5', 'CLUSTERtrain_4', 'CLUSTERtrain_48']
#
# =============================================================
#
# >>> Cluster 1 :
#
# >>> Contains trained users :
#
# >>> ['CLUSTERtrain_8', 'CLUSTERtrain_30', 'CLUSTERtrain_24', 'CLUSTERtrain_20', 'CLUSTERtrain_10', 'CLUSTERtrain_16', 'CLUSTERtrain_15', 'CLUSTERtrain_3']
#
# All the historical data for each cluster is ready!
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Start Searching The best recommender<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Current Checking Recommender is >>>> [[ DecisionTreeClassifier ]]
#
# Time Consuming for this fit is :0.22274398803710938
#
# ===> val. score: 0.5126050420168067
#
# ===> best parameter: OrderedDict([('criterion', 'entropy'), ('max_depth', 3), ('max_features', 16), ('max_leaf_nodes', 7), ('min_samples_leaf', 6)])
#
# ===> Actual Estimator is: DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=3, max_features=16, max_leaf_nodes=7,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=6, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')
#
#
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Current Checking Recommender is >>>> [[ LogisticRegression ]]
#
# Time Consuming for this fit is :6.356940031051636
#
# ===> val. score: 0.4849673202614379
#
# ===> best parameter: OrderedDict([('C', 0.7955804025166714), ('fit_intercept', False), ('solver', 'lbfgs')])
#
# ===> Actual Estimator is: LogisticRegression(C=0.7955804025166714, class_weight=None, dual=False,
#                    fit_intercept=False, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
#
#
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Current Checking Recommender is >>>> [[ RandomForestClassifier ]]
#
# Time Consuming for this fit is :5.697268962860107
#
# ===> val. score: 0.5025210084033613
#
# ===> best parameter: OrderedDict([('bootstrap', True), ('criterion', 'gini'), ('max_depth', 19), ('max_features', 24), ('n_estimators', 12)])
#
# ===> Actual Estimator is: RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=19, max_features=24,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=12,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
#
#
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Current Checking Recommender is >>>> [[ KNeighborsClassifier_uniform ]]
#
# Time Consuming for this fit is :18.183914184570312
#
# ===> val. score: 0.4991596638655462
#
# ===> best parameter: OrderedDict([('algorithm', 'kd_tree'), ('n_neighbors', 20)])
#
# ===> Actual Estimator is: KNeighborsClassifier(algorithm='kd_tree', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=20, p=2,
#                      weights='uniform')
#
#
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Current Checking Recommender is >>>> [[ KNeighborsClassifier_distance ]]
#
# Time Consuming for this fit is :234.1718647480011
#
# ===> val. score: 0.49411764705882355
#
# ===> best parameter: OrderedDict([('algorithm', 'ball_tree'), ('n_neighbors', 26), ('p', 3)])
#
# ===> Actual Estimator is: KNeighborsClassifier(algorithm='ball_tree', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=26, p=3,
#                      weights='distance')
#
#
#
# ----------------------------------------------------------------------------------------------------------------
#
# SEARCHING FINISH :
#  The best recommder is DecisionTreeClassifier
#  its tune parameter is OrderedDict([('criterion', 'entropy'), ('max_depth', 3), ('max_features', 16), ('max_leaf_nodes', 7), ('min_samples_leaf', 6)])
#  its score is 0.5126050420168067
#  its evaluation score is 0 (0 means do not have the evaluation set)
#  its model train time is 0.22274398803710938
#  The actually estimator is DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=3, max_features=16, max_leaf_nodes=7,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=6, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')
#
# ----------------------------------------------------------------------------------------------------------------
#
# MODEL HAS BEEN SAVED IN  /Users/gleonardo/Downloads/TravelOffer_Recommendation-main/TEST_DATA/CLUSTER_FOLDER/CLUSTER_REC_MODEL/best_model_Cluster_0_Records_all_latest.m
# INFO HAS BEEN SAVED IN  /Users/gleonardo/Downloads/TravelOffer_Recommendation-main/TEST_DATA/CLUSTER_FOLDER/CLUSTER_REC_MODEL/best_model_Cluster_0_Records_all_latest.npy
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Start Searching The best recommender<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Current Checking Recommender is >>>> [[ DecisionTreeClassifier ]]
#
# Time Consuming for this fit is :0.0933377742767334
#
# ===> val. score: 0.5135297654840649
#
# ===> best parameter: OrderedDict([('criterion', 'entropy'), ('max_depth', 4), ('max_features', 17), ('max_leaf_nodes', 10), ('min_samples_leaf', 12)])
#
# ===> Actual Estimator is: DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=4, max_features=17, max_leaf_nodes=10,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=12, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')
#
#
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Current Checking Recommender is >>>> [[ LogisticRegression ]]
#
# Time Consuming for this fit is :0.3490288257598877
#
# ===> val. score: 0.49007817197835235
#
# ===> best parameter: OrderedDict([('C', 0.5903442411580019), ('fit_intercept', True), ('solver', 'lbfgs')])
#
# ===> Actual Estimator is: LogisticRegression(C=0.5903442411580019, class_weight=None, dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
#
#
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Current Checking Recommender is >>>> [[ RandomForestClassifier ]]
#
# Time Consuming for this fit is :6.612675905227661
#
# ===> val. score: 0.4954900781719784
#
# ===> best parameter: OrderedDict([('bootstrap', False), ('criterion', 'entropy'), ('max_depth', 18), ('max_features', 34), ('n_estimators', 78)])
#
# ===> Actual Estimator is: RandomForestClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=18, max_features=34,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=78,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
#
#
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Current Checking Recommender is >>>> [[ KNeighborsClassifier_uniform ]]
#
# Time Consuming for this fit is :1.228745937347412
#
# ===> val. score: 0.49969933854479853
#
# ===> best parameter: OrderedDict([('algorithm', 'ball_tree'), ('n_neighbors', 20)])
#
# ===> Actual Estimator is: KNeighborsClassifier(algorithm='ball_tree', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=20, p=2,
#                      weights='uniform')
#
#
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Current Checking Recommender is >>>> [[ KNeighborsClassifier_distance ]]
#
# Time Consuming for this fit is :9.881953954696655
#
# ===> val. score: 0.5225496091401083
#
# ===> best parameter: OrderedDict([('algorithm', 'kd_tree'), ('n_neighbors', 5), ('p', 6)])
#
# ===> Actual Estimator is: KNeighborsClassifier(algorithm='kd_tree', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=6,
#                      weights='distance')
#
#
#
# ----------------------------------------------------------------------------------------------------------------
#
# SEARCHING FINISH :
#  The best recommder is KNeighborsClassifier_distance
#  its tune parameter is OrderedDict([('algorithm', 'kd_tree'), ('n_neighbors', 5), ('p', 6)])
#  its score is 0.5225496091401083
#  its evaluation score is 0 (0 means do not have the evaluation set)
#  its model train time is 9.881953954696655
#  The actually estimator is KNeighborsClassifier(algorithm='kd_tree', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=6,
#                      weights='distance')
#
# ----------------------------------------------------------------------------------------------------------------
#
# MODEL HAS BEEN SAVED IN  /Users/gleonardo/Downloads/TravelOffer_Recommendation-main/TEST_DATA/CLUSTER_FOLDER/CLUSTER_REC_MODEL/best_model_Cluster_1_Records_all_latest.m
# INFO HAS BEEN SAVED IN  /Users/gleonardo/Downloads/TravelOffer_Recommendation-main/TEST_DATA/CLUSTER_FOLDER/CLUSTER_REC_MODEL/best_model_Cluster_1_Records_all_latest.npy
# The ClusterNo for the user is : [0]
# DONE! THE Pre trained model has been copied into the cold user

# %%
test.API_USER_TRAIN(test.COLD_USER,reClusterTag=False)
# Out:
# The ClusterNo for the user is : [0]
# DONE! THE Pre trained model has been copied into the cold user

# %%
test.help()
# Out:
# ==================================================================
#
# API_USER_FEEDBACK(self,username,boughtID_list,response_code):
#
#
#
# [username] name of the user who bought the offer, if not given username will be 'TESTUSER1'
#
# [boughtID_list] a list contains all the travel offer ID that the user has bought already.
#
# [response_code] used to find the travel offer list satisfied the request. If not given, list will be in 999.csv.
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# [username] self.OLD_USER ,try to not use self.COLD_USER or it will make the cold user to be an old user.
#
# [boughtID_list] enter by the user.

# %%
response_code = test.API_USER_PREDICT(test.OLD_USER,test.req)
# Out:
# >>>
# The request of TEST USER has been generated in
#  /Users/gleonardo/Downloads/TravelOffer_Recommendation-main/TEST_DATA/RequestJson/requestInfo.json
# =======================================================================================================
#
# Dear OLDUSER1 :
#
# According to your request, we recommend you consider the followiing travel offers.
#
#      Travel Offer ID Starting point Destination  \
# 1   ['Local type', 'Water transport', 'Telecabin']       None
# 2   ['Local type', 'Water transport', 'Telecabin']      Max 3
# 3   ['Local type', 'Water transport', 'Telecabin']      Max 2
# 4   ['Local type', 'Water transport', 'Telecabin']      Max 2
# 5   ['Local type', 'Water transport', 'Telecabin']  Unlimited
# 6   ['Local type', 'Water transport', 'Telecabin']      Max 2
# 7   ['Local type', 'Water transport', 'Telecabin']      Max 3
# 8   ['Local type', 'Water transport', 'Telecabin']      Max 4
# 9   ['Local type', 'Water transport', 'Telecabin']      Max 3
# 10  ['Local type', 'Water transport', 'Telecabin']      Max 4
# 11  ['Local type', 'Water transport', 'Telecabin']      Max 3
# 12  ['Local type', 'Water transport', 'Telecabin']      Max 1
# 13  ['Local type', 'Water transport', 'Telecabin']  Unlimited
# 14  ['Local type', 'Water transport', 'Telecabin']      Max 3
# 15  ['Local type', 'Water transport', 'Telecabin']      Max 3
# 16  ['Local type', 'Water transport', 'Telecabin']       None
# 17  ['Local type', 'Water transport', 'Telecabin']      Max 2
# 18  ['Local type', 'Water transport', 'Telecabin']       None
# 19  ['Local type', 'Water transport', 'Telecabin']      Max 2
# 20  ['Local type', 'Water transport', 'Telecabin']      Max 4
# 21  ['Local type', 'Water transport', 'Telecabin']  Unlimited
# 22  ['Local type', 'Water transport', 'Telecabin']      Max 1
# 23  ['Local type', 'Water transport', 'Telecabin']      Max 2
# 24  ['Local type', 'Water transport', 'Telecabin']      Max 1
# 25  ['Local type', 'Water transport', 'Telecabin']  Unlimited
# 26  ['Local type', 'Water transport', 'Telecabin']       None
# 27  ['Local type', 'Water transport', 'Telecabin']      Max 1
# 28  ['Local type', 'Water transport', 'Telecabin']      Max 3
#
#    Transfer duration  Walking distance to stop  Walking speed  \
# 0    At least 25 min                     4000m           Slow
# 1    At least 45 min                     1000m           Slow
# 2    At least 35 min                     3000m           Slow
# 3    At least 25 min                     3500m           Slow
# 4    At least 35 min                     4000m           Slow
# 5    At least 10 min                     1500m           Slow
# 6    At least 45 min                     3500m           Slow
# 7    At least 20 min                     4500m           Slow
# 8             normal                     3000m           Slow
# 9    At least 45 min                     3500m           Slow
# 10   At least 25 min                     3000m           Slow
# 11   At least 40 min                     4000m           Slow
# 12   At least 40 min                     2500m           Slow
# 13   At least 25 min                     3000m           Slow
# 14            normal                     4500m           Slow
# 15   At least 10 min                     3000m           Slow
# 16   At least 15 min                      500m           Slow
# 17   At least 15 min                     3000m           Slow
# 18   At least 10 min                      500m           Slow
# 19   At least 15 min                      500m           Slow
# 20   At least 15 min                      500m           Slow
# 21   At least 20 min                     2500m           Slow
# 22   At least 15 min                     1000m           Slow
# 23   At least 30 min                     1500m           Slow
# 24   At least 30 min                     2000m           Slow
# 25   At least 35 min                     3000m           Slow
# 26   At least 25 min                     4500m           Slow
# 27            normal                     3500m           Slow
# 28   At least 40 min                     1000m           Slow
#
#     Cycling distance to stop  Cycling speed  Driving speed  Bought Tag
# 0                     18500m           Fast           Fast           0
# 1                      9500m           Fast           Fast           0
# 2                      9500m           Fast           Fast           0
# 3                     16000m           Fast           Fast           0
# 4                     19000m           Fast           Fast           0
# 5                      5000m           Fast           Fast           0
# 6                     14500m           Fast           Fast           0
# 7                      9000m           Fast           Fast           0
# 8                     15000m           Fast           Fast           0
# 9                      6500m           Fast           Fast           0
# 10                     3000m           Fast           Fast           0
# 11                    10000m           Fast           Fast           0
# 12                    14000m           Fast           Fast           0
# 13                     2500m           Fast           Fast           0
# 14                     8500m           Fast           Fast           0
# 15                    16500m           Fast           Fast           0
# 16                     9000m           Fast           Fast           0
# 17                    14000m           Fast           Fast           0
# 18                    18500m           Fast           Fast           0
# 19                     2500m           Fast           Fast           0
# 20                    13500m           Fast           Fast           0
# 21                     4000m           Fast           Fast           0
# 22                     8000m           Fast           Fast           0
# 23                    14000m           Fast           Fast           0
# 24                     6000m           Fast           Fast           0
# 25                     2000m           Fast           Fast           0
# 26                    18000m           Fast           Fast           0
# 27                     6000m           Fast           Fast           0
# 28                     2000m           Fast           Fast           1
#
# [29 rows x 45 columns]

# %%
test.CreateOldUser('Ali')
# Out:
# Profile Has Been Updated in  /Users/gleonardo/Downloads/TravelOffer_Recommendation-main/TEST_DATA/USER_PROFILE/Ali.csv
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-c3d6cc3da52c> in <module>
# ----> 1 test.CreateOldUser('Ali')
#
# ~/Downloads/TravelOffer_Recommendation-main/API_Main.py in CreateOldUser(self, username, df_profile)
#     370
#     371         staProfile = df_profile.to_dict
# --> 372         self.his._GenerateHis2File(username,staticChangeTag=False,staProfile=staProfile)
#     373
#     374
#
# ~/Downloads/TravelOffer_Recommendation-main/LEARNER.py in _GenerateHis2File(self, username, staticChangeTag, staProfile)
#     445
#     446     def _GenerateHis2File(self,username,staticChangeTag=True,staProfile=None):
# --> 447         df = self.historical_Generator(username,staticChangeTag=staticChangeTag,staProfile=staProfile)
#     448         self.res2csv(df, self.TEST_HISTORICAL_DATA_PATH, username+'.csv')
#     449         print('\n>>>\nUser {} `s historical records has been generated in the file \n{}\n'.format(username,self.TEST_HISTORICAL_DATA_PATH))
#
# ~/Downloads/TravelOffer_Recommendation-main/LEARNER.py in historical_Generator(self, username, staticChangeTag, staProfile)
#     341         TravelOffer = {"TimeStamp":TimeStamp}
#     342         TravelOffer.update({"User ID":userID })
# --> 343         TravelOffer.update(staticProfile)
#     344
#     345         #change the number to generate different amount of his records
#
# TypeError: 'method' object is not iterable

# %%
test.API_USER_TRAIN('Ali')
# Out:
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Start Searching The best recommender<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Current Checking Recommender is >>>> [[ SVC ]]
#
# Time Consuming for this fit is :0.4056358337402344
#
# ===> val. score: 0.5507246376811594
#
# ===> best parameter: OrderedDict([('C', 4.201861004948938), ('degree', 2), ('gamma', 0.008983773683519197), ('kernel', 'rbf'), ('probability', True)])
#
# ===> Actual Estimator is: SVC(C=4.201861004948938, break_ties=False, cache_size=200, class_weight=None,
#     coef0=0.0, decision_function_shape='ovr', degree=2,
#     gamma=0.008983773683519197, kernel='rbf', max_iter=-1, probability=True,
#     random_state=None, shrinking=True, tol=0.001, verbose=False)
#
#
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Current Checking Recommender is >>>> [[ DecisionTreeClassifier ]]
#
# Time Consuming for this fit is :0.03047490119934082
#
# ===> val. score: 0.5362318840579711
#
# ===> best parameter: OrderedDict([('criterion', 'entropy'), ('max_depth', 4), ('max_features', 23), ('max_leaf_nodes', 16), ('min_samples_leaf', 6)])
#
# ===> Actual Estimator is: DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=4, max_features=23, max_leaf_nodes=16,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=6, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')
#
#
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Current Checking Recommender is >>>> [[ LogisticRegression ]]
#
# Time Consuming for this fit is :0.22417306900024414
#
# ===> val. score: 0.4444444444444444
#
# ===> best parameter: OrderedDict([('C', 0.7305832930138666), ('fit_intercept', True), ('solver', 'lbfgs')])
#
# ===> Actual Estimator is: LogisticRegression(C=0.7305832930138666, class_weight=None, dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
#
#
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Current Checking Recommender is >>>> [[ RandomForestClassifier ]]
#
# Time Consuming for this fit is :0.7598741054534912
#
# ===> val. score: 0.5603864734299517
#
# ===> best parameter: OrderedDict([('bootstrap', False), ('criterion', 'entropy'), ('max_depth', 34), ('max_features', 35), ('n_estimators', 39)])
#
# ===> Actual Estimator is: RandomForestClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=34, max_features=35,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=39,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
#
#
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Current Checking Recommender is >>>> [[ KNeighborsClassifier_uniform ]]
#
# Time Consuming for this fit is :0.05710411071777344
#
# ===> val. score: 0.5120772946859904
#
# ===> best parameter: OrderedDict([('algorithm', 'kd_tree'), ('n_neighbors', 17)])
#
# ===> Actual Estimator is: KNeighborsClassifier(algorithm='kd_tree', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=17, p=2,
#                      weights='uniform')
#
#
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Current Checking Recommender is >>>> [[ KNeighborsClassifier_distance ]]
#
# Time Consuming for this fit is :0.11546492576599121
#
# ===> val. score: 0.5072463768115942
#
# ===> best parameter: OrderedDict([('algorithm', 'brute'), ('n_neighbors', 6), ('p', 1)])
#
# ===> Actual Estimator is: KNeighborsClassifier(algorithm='brute', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=6, p=1,
#                      weights='distance')
#
#
#
# ----------------------------------------------------------------------------------------------------------------
#
# SEARCHING FINISH :
#  The best recommder is RandomForestClassifier
#  its tune parameter is OrderedDict([('bootstrap', False), ('criterion', 'entropy'), ('max_depth', 34), ('max_features', 35), ('n_estimators', 39)])
#  its score is 0.5603864734299517
#  its evaluation score is 0 (0 means do not have the evaluation set)
#  its model train time is 0.7598741054534912
#  The actually estimator is RandomForestClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=34, max_features=35,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=39,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
#
# ----------------------------------------------------------------------------------------------------------------
#
# MODEL HAS BEEN SAVED IN  /Users/gleonardo/Downloads/TravelOffer_Recommendation-main/TEST_DATA/CLASSIFIER/MODEL/best_model_Ali_all_latest.m
# INFO HAS BEEN SAVED IN  /Users/gleonardo/Downloads/TravelOffer_Recommendation-main/TEST_DATA/CLASSIFIER/INFO/best_model_Ali_all_latest.npy

# %%
test.API_USER_PREDICT('Ali',req=test.req)
# Out:
# 16  Tehran    Iran  ['Grand Voyageur', 'Golden Card', 'Cartafreccia']
# 17  Tehran    Iran  ['Grand Voyageur', 'Golden Card', 'Cartafreccia']
# 18  Tehran    Iran  ['Grand Voyageur', 'Golden Card', 'Cartafreccia']
# 19  Tehran    Iran  ['Grand Voyageur', 'Golden Card', 'Cartafreccia']
#
#                                          Payment Card  \
# 0   ['Apple Wallet', 'Google Wallet', 'Visa', 'Mas...
# 1   ['Apple Wallet', 'Google Wallet', 'Visa', 'Mas...
# 2   ['Apple Wallet', 'Google Wallet', 'Visa', 'Mas...
# 3   ['Apple Wallet', 'Google Wallet', 'Visa', 'Mas...
# 4   ['Apple Wallet', 'Google Wallet', 'Visa', 'Mas...
# 5   ['Apple Wallet', 'Google Wallet', 'Visa', 'Mas...
# 6   ['Apple Wallet', 'Google Wallet', 'Visa', 'Mas...
# 7   ['Apple Wallet', 'Google Wallet', 'Visa', 'Mas...
# 8   ['Apple Wallet', 'Google Wallet', 'Visa', 'Mas...
# 9   ['Apple Wallet', 'Google Wallet', 'Visa', 'Mas...
# 10  ['Apple Wallet', 'Google Wallet', 'Visa', 'Mas...
# 11  ['Apple Wallet', 'Google Wallet', 'Visa', 'Mas...
# 12  ['Apple Wallet', 'Google Wallet', 'Visa', 'Mas...
# 13  ['Apple Wallet', 'Google Wallet', 'Visa', 'Mas...
# 14  ['Apple Wallet', 'Google Wallet', 'Visa', 'Mas...
# 15  ['Apple Wallet', 'Google Wallet', 'Visa', 'Mas...
# 16  ['Apple Wallet', 'Google Wallet', 'Visa', 'Mas...
# 17  ['Apple Wallet', 'Google Wallet', 'Visa', 'Mas...
# 18  ['Apple Wallet', 'Google Wallet', 'Visa', 'Mas...
# 19  ['Apple Wallet', 'Google Wallet', 'Visa', 'Mas...
#
#                                              PRM Type  \
# 0   ['Pregnant woman', 'Older person', 'Person wit...
# 1   ['Pregnant woman', 'Older person', 'Person wit...
# 2   ['Pregnant woman', 'Older person', 'Person wit...
# 3   ['Pregnant woman', 'Older person', 'Person wit...
# 4   ['Pregnant woman', 'Older person', 'Person wit...
# 5   ['Pregnant woman', 'Older person', 'Person wit...
# 6   ['Pregnant woman', 'Older person', 'Person wit...
# 7   ['Pregnant woman', 'Older person', 'Person wit...
# 8   ['Pregnant woman', 'Older person', 'Person wit...
# 9   ['Pregnant woman', 'Older person', 'Person wit...
# 10  ['Pregnant woman', 'Older person', 'Person wit...
# 11  ['Pregnant woman', 'Older person', 'Person wit...
# 12  ['Pregnant woman', 'Older person', 'Person wit...
# 13  ['Pregnant woman', 'Older person', 'Person wit...
# 14  ['Pregnant woman', 'Older person', 'Person wit...
# 15  ['Pregnant woman', 'Older person', 'Person wit...
# 16  ['Pregnant woman', 'Older person', 'Person wit...
# 17  ['Pregnant woman', 'Older person', 'Person wit...
# 18  ['Pregnant woman', 'Older person', 'Person wit...
# 19  ['Pregnant woman', 'Older person', 'Person wit...
#
#                     Preferred means of transportation  ...      Arrival time  \
# 0   ['Intercity', 'Urban', 'Funicular', 'Trolely B...  ...  2021-06-15 08:53
# 1   ['Intercity', 'Urban', 'Funicular', 'Trolely B...  ...  2021-06-15 08:53
# 2   ['Intercity', 'Urban', 'Funicular', 'Trolely B...  ...  2021-06-15 08:53
# 3   ['Intercity', 'Urban', 'Funicular', 'Trolely B...  ...  2021-06-15 08:53
# 4   ['Intercity', 'Urban', 'Funicular', 'Trolely B...  ...  2021-06-15 08:53
# 5   ['Intercity', 'Urban', 'Funicular', 'Trolely B...  ...  2021-06-15 08:53
# 6   ['Intercity', 'Urban', 'Funicular', 'Trolely B...  ...  2021-06-15 08:53
# 7   ['Intercity', 'Urban', 'Funicular', 'Trolely B...  ...  2021-06-15 08:53
# 8   ['Intercity', 'Urban', 'Funicular', 'Trolely B...  ...  2021-06-15 08:53
# 9   ['Intercity', 'Urban', 'Funicular', 'Trolely B...  ...  2021-06-15 08:53
# 10  ['Intercity', 'Urban', 'Funicular', 'Trolely B...  ...  2021-06-15 08:53
# 11  ['Intercity', 'Urban', 'Funicular', 'Trolely B...  ...  2021-06-15 08:53
# 12  ['Intercity', 'Urban', 'Funicular', 'Trolely B...  ...  2021-06-15 08:53
# 13  ['Intercity', 'Urban', 'Funicular', 'Trolely B...  ...  2021-06-15 08:53
# 14  ['Intercity', 'Urban', 'Funicular', 'Trolely B...  ...  2021-06-15 08:53
# 15  ['Intercity', 'Urban', 'Funicular', 'Trolely B...  ...  2021-06-15 08:53
# 16  ['Intercity', 'Urban', 'Funicular', 'Trolely B...  ...  2021-06-15 08:53
# 17  ['Intercity', 'Urban', 'Funicular', 'Trolely B...  ...  2021-06-15 08:53
# 18  ['Intercity', 'Urban', 'Funicular', 'Trolely B...  ...  2021-06-15 08:53
# 19  ['Intercity', 'Urban', 'Funicular', 'Trolely B...  ...  2021-06-15 08:53
#
#                        Services  Transfers Transfer duration  \
# 0   ['Local type', 'Telecabin']       None   At least 40 min
# 1   ['Local type', 'Telecabin']      Max 1   At least 15 min
# 2   ['Local type', 'Telecabin']      Max 1   At least 25 min
# 3   ['Local type', 'Telecabin']      Max 2   At least 25 min
# 4   ['Local type', 'Telecabin']      Max 4   At least 30 min
# 5   ['Local type', 'Telecabin']  Unlimited   At least 40 min
# 6   ['Local type', 'Telecabin']  Unlimited   At least 30 min
# 7   ['Local type', 'Telecabin']  Unlimited   At least 45 min
# 8   ['Local type', 'Telecabin']      Max 4   At least 15 min
# 9   ['Local type', 'Telecabin']      Max 4   At least 35 min
# 10  ['Local type', 'Telecabin']  Unlimited   At least 20 min
# 11  ['Local type', 'Telecabin']      Max 3   At least 15 min
# 12  ['Local type', 'Telecabin']      Max 2   At least 40 min
# 13  ['Local type', 'Telecabin']      Max 2            normal
# 14  ['Local type', 'Telecabin']       None   At least 20 min
# 15  ['Local type', 'Telecabin']  Unlimited            normal
# 16  ['Local type', 'Telecabin']      Max 4   At least 35 min
# 17  ['Local type', 'Telecabin']       None            normal
# 18  ['Local type', 'Telecabin']      Max 2   At least 15 min
# 19  ['Local type', 'Telecabin']      Max 4   At least 35 min
#
#     Walking distance to stop  Walking speed  Cycling distance to stop  \
# 0                      3000m           Slow                     9500m
# 1                      4000m           Slow                    16500m
# 2                      3000m           Slow                    11000m
# 3                       500m           Slow                     6000m
# 4                      3500m           Slow                    17000m
# 5                      1500m           Slow                     3500m
# 6                      2000m           Slow                     3000m
# 7                      3000m           Slow                    16500m
# 8                      1000m           Slow                    14500m
# 9                      3000m           Slow                    11000m
# 10                     2000m           Slow                    13000m
# 11                     3000m           Slow                     7500m
# 12                     4000m           Slow                     3500m
# 13                     3500m           Slow                    17000m
# 14                     3000m           Slow                    17000m
# 15                      500m           Slow                    15000m
# 16                     4000m           Slow                    16000m
# 17                     3500m           Slow                    12000m
# 18                      500m           Slow                     3000m
# 19                     1500m           Slow                     6000m
#
#     Cycling speed  Driving speed  Bought Tag
# 0            Fast           Fast           0
# 1            Fast           Fast           0
# 2            Fast           Fast           0
# 3            Fast           Fast           0
# 4            Fast           Fast           0
# 5            Fast           Fast           0
# 6            Fast           Fast           0
# 7            Fast           Fast           0
# 8            Fast           Fast           0
# 9            Fast           Fast           0
# 10           Fast           Fast           0
# 11           Fast           Fast           0
# 12           Fast           Fast           0
# 13           Fast           Fast           0
# 14           Fast           Fast           0
# 15           Fast           Fast           0
# 16           Fast           Fast           0
# 17           Fast           Fast           0
# 18           Fast           Fast           0
# 19           Fast           Fast           1
#
# [20 rows x 45 columns]

# %%
newuser = 'Chaofeng'
new_profile = test.df_profile
new_profile.loc[0,'User ID'] = newuser
test.API_USER_PREDICT(newuser,req=test.req,df_profile=new_profile)
# Out:
# Profile Has Been Updated in  /Users/gleonardo/Downloads/TravelOffer_Recommendation-main/TEST_DATA/USER_PROFILE/Chaofeng.csv
#
# >>>
# The request of TEST USER has been generated in
#  /Users/gleonardo/Downloads/TravelOffer_Recommendation-main/TEST_DATA/RequestJson/requestInfo.json
# The ClusterNo for the user is : [0]
# DONE! THE Pre trained model has been copied into the cold user
# =======================================================================================================
#
# Dear Chaofeng :
#
# According to your request, we recommend you consider the followiing travel offers.
#
#      Travel Offer ID Starting point Destination                      Via  \
# 0    202106140051560          Milan      Dublin  ['Berlin', 'Frankfurt']
# 1    202106140051561          Milan      Dublin  ['Berlin', 'Frankfurt']
# 2    202106140051568          Milan      Dublin  ['Berlin', 'Frankfurt']
# 3    202106140051562          Milan      Dublin  ['Berlin', 'Frankfurt']
# 4    202106140051563          Milan      Dublin  ['Berlin', 'Frankfurt']
# 5    202106140051564          Milan      Dublin  ['Berlin', 'Frankfurt']
# 6    202106140051565          Milan      Dublin  ['Berlin', 'Frankfurt']
# 7    202106140051566          Milan      Dublin  ['Berlin', 'Frankfurt']
# 8    202106140051567          Milan      Dublin  ['Berlin', 'Frankfurt']
# 9    202106140051569          Milan      Dublin  ['Berlin', 'Frankfurt']
# 10  2021061400515616          Milan      Dublin  ['Berlin', 'Frankfurt']
# 11  2021061400515610          Milan      Dublin  ['Berlin', 'Frankfurt']
